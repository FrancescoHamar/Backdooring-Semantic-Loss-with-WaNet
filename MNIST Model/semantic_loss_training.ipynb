# %%
# Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from semantic_loss_pytorch import SemanticLoss

# %%
# Hyperparameters and Configuration
batch_size = 64
epochs = 5
constraint_sdd = "constraint.sdd"
constraint_vtree = "constraint.vtree"
use_semantic_loss = True

# %%
# Define the MLP Model
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.bn1 = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, 64)
        self.bn2 = nn.BatchNorm1d(64)
        self.dropout = nn.Dropout(0.3)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.fc3(x)
        return x

# %%
# Accuracy Computation
def compute_accuracy(logits, labels):
    preds = torch.argmax(logits, dim=1)
    correct = (preds == labels).float().sum()
    return correct / len(labels)

# %%
# Training Step
def train_step(model, images, labels, optimizer, sl_module=None):
    model.train()
    logits = model(images)
    sl = 0

    ce_loss = F.cross_entropy(logits, labels)
    if sl_module is not None:
        sl = sl_module(logits=logits)
        loss = ce_loss + 0.1 * sl
    else:
        loss = ce_loss

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    acc = compute_accuracy(logits, labels)
    return loss.item(), ce_loss.item(), float(sl), acc.item()

# %%
# Training and Evaluation
transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True,
                                          transform=transforms.Compose([
                                              transforms.ToTensor(),
                                              transforms.Normalize((0.1307,), (0.3081,))
                                          ]))

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

model = MLP()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
sl_module = SemanticLoss(constraint_sdd, constraint_vtree) if use_semantic_loss else None

# %%
# Main Training Loop
for epoch in range(epochs):
    for step, (images, labels) in enumerate(train_loader):
        loss, ce_loss, sl, acc = train_step(model, images, labels, optimizer, sl_module)
        if step % 100 == 0:
            print(f"Epoch {epoch}, Step {step}: "
                  f"Loss: {loss:.4f}, Cross Entropy: {ce_loss:.4f}, Semantic Loss: {sl:.4f}, Accuracy: {acc:.4f}")
    scheduler.step()

    # 🔍 Evaluation
    model.eval()
    test_acc = 0
    with torch.no_grad():
        for images, labels in test_loader:
            logits = model(images)
            test_acc += compute_accuracy(logits, labels).item()
    test_acc /= len(test_loader)
    print(f"Epoch {epoch} - Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 0, Step 0: Loss: 2.8552, Cross Entropy: 2.4254, Semantic Loss: 4.2983, Accuracy: 0.1406
# Epoch 0, Step 100: Loss: 0.5670, Cross Entropy: 0.4712, Semantic Loss: 0.9580, Accuracy: 0.8438
# Epoch 0, Step 200: Loss: 0.5388, Cross Entropy: 0.4792, Semantic Loss: 0.5961, Accuracy: 0.8906
# Epoch 0, Step 300: Loss: 0.3120, Cross Entropy: 0.2414, Semantic Loss: 0.7065, Accuracy: 0.9375
# Epoch 0, Step 400: Loss: 0.2408, Cross Entropy: 0.1779, Semantic Loss: 0.6295, Accuracy: 0.9375
# Epoch 0, Step 500: Loss: 0.5037, Cross Entropy: 0.4445, Semantic Loss: 0.5922, Accuracy: 0.8438
# Epoch 0, Step 600: Loss: 0.4624, Cross Entropy: 0.3888, Semantic Loss: 0.7358, Accuracy: 0.9219
# Epoch 0, Step 700: Loss: 0.1714, Cross Entropy: 0.1345, Semantic Loss: 0.3693, Accuracy: 0.9531
# Epoch 0, Step 800: Loss: 0.3669, Cross Entropy: 0.2950, Semantic Loss: 0.7191, Accuracy: 0.9062
# Epoch 0, Step 900: Loss: 0.1394, Cross Entropy: 0.1109, Semantic Loss: 0.2847, Accuracy: 0.9844
# Epoch 0 - Test Accuracy: 0.9615
# Epoch 1, Step 0: Loss: 0.2487, Cross Entropy: 0.1861, Semantic Loss: 0.6267, Accuracy: 0.9219
# Epoch 1, Step 100: Loss: 0.2392, Cross Entropy: 0.1802, Semantic Loss: 0.5908, Accuracy: 0.9531
# Epoch 1, Step 200: Loss: 0.2442, Cross Entropy: 0.1719, Semantic Loss: 0.7238, Accuracy: 0.9219
# Epoch 1, Step 300: Loss: 0.2556, Cross Entropy: 0.1723, Semantic Loss: 0.8333, Accuracy: 0.9688
# Epoch 1, Step 400: Loss: 0.1615, Cross Entropy: 0.1033, Semantic Loss: 0.5817, Accuracy: 0.9688
# Epoch 1, Step 500: Loss: 0.2395, Cross Entropy: 0.1662, Semantic Loss: 0.7322, Accuracy: 0.9375
# Epoch 1, Step 600: Loss: 0.3683, Cross Entropy: 0.2924, Semantic Loss: 0.7591, Accuracy: 0.9219
# Epoch 1, Step 700: Loss: 0.3106, Cross Entropy: 0.2172, Semantic Loss: 0.9347, Accuracy: 0.9688
# Epoch 1, Step 800: Loss: 0.1950, Cross Entropy: 0.1453, Semantic Loss: 0.4974, Accuracy: 0.9375
# Epoch 1, Step 900: Loss: 0.1769, Cross Entropy: 0.1422, Semantic Loss: 0.3470, Accuracy: 0.9531
# Epoch 1 - Test Accuracy: 0.9717
# Epoch 2, Step 0: Loss: 0.2095, Cross Entropy: 0.1568, Semantic Loss: 0.5266, Accuracy: 0.9375
# Epoch 2, Step 100: Loss: 0.3682, Cross Entropy: 0.3113, Semantic Loss: 0.5691, Accuracy: 0.8750
# Epoch 2, Step 200: Loss: 0.2331, Cross Entropy: 0.1617, Semantic Loss: 0.7142, Accuracy: 0.9688
# Epoch 2, Step 300: Loss: 0.1847, Cross Entropy: 0.1249, Semantic Loss: 0.5979, Accuracy: 0.9688
# Epoch 2, Step 400: Loss: 0.3635, Cross Entropy: 0.3033, Semantic Loss: 0.6021, Accuracy: 0.9219
# Epoch 2, Step 500: Loss: 0.1513, Cross Entropy: 0.1000, Semantic Loss: 0.5133, Accuracy: 0.9688
# Epoch 2, Step 600: Loss: 0.1631, Cross Entropy: 0.1152, Semantic Loss: 0.4791, Accuracy: 0.9688
# Epoch 2, Step 700: Loss: 0.1648, Cross Entropy: 0.1207, Semantic Loss: 0.4418, Accuracy: 0.9688
# Epoch 2, Step 800: Loss: 0.4623, Cross Entropy: 0.4035, Semantic Loss: 0.5880, Accuracy: 0.9219
# Epoch 2, Step 900: Loss: 0.1837, Cross Entropy: 0.1017, Semantic Loss: 0.8207, Accuracy: 0.9375
# Epoch 2 - Test Accuracy: 0.9749
# Epoch 3, Step 0: Loss: 0.2591, Cross Entropy: 0.2106, Semantic Loss: 0.4849, Accuracy: 0.9375
# Epoch 3, Step 100: Loss: 0.1870, Cross Entropy: 0.1605, Semantic Loss: 0.2651, Accuracy: 0.9531
# Epoch 3, Step 200: Loss: 0.2663, Cross Entropy: 0.2101, Semantic Loss: 0.5619, Accuracy: 0.9219
# Epoch 3, Step 300: Loss: 0.2043, Cross Entropy: 0.1538, Semantic Loss: 0.5050, Accuracy: 0.9531
# Epoch 3, Step 400: Loss: 0.2933, Cross Entropy: 0.2231, Semantic Loss: 0.7025, Accuracy: 0.9219
# Epoch 3, Step 500: Loss: 0.1313, Cross Entropy: 0.0895, Semantic Loss: 0.4182, Accuracy: 0.9688
# Epoch 3, Step 600: Loss: 0.4455, Cross Entropy: 0.3892, Semantic Loss: 0.5630, Accuracy: 0.8750
# Epoch 3, Step 700: Loss: 0.1639, Cross Entropy: 0.0912, Semantic Loss: 0.7266, Accuracy: 0.9844
# Epoch 3, Step 800: Loss: 0.1814, Cross Entropy: 0.1179, Semantic Loss: 0.6343, Accuracy: 0.9688
# Epoch 3, Step 900: Loss: 0.3124, Cross Entropy: 0.2527, Semantic Loss: 0.5966, Accuracy: 0.9375
# Epoch 3 - Test Accuracy: 0.9756
# Epoch 4, Step 0: Loss: 0.1407, Cross Entropy: 0.0705, Semantic Loss: 0.7016, Accuracy: 0.9844
# Epoch 4, Step 100: Loss: 0.2476, Cross Entropy: 0.1812, Semantic Loss: 0.6641, Accuracy: 0.9219
# Epoch 4, Step 200: Loss: 0.3231, Cross Entropy: 0.2626, Semantic Loss: 0.6048, Accuracy: 0.9062
# Epoch 4, Step 300: Loss: 0.1341, Cross Entropy: 0.0995, Semantic Loss: 0.3459, Accuracy: 0.9688
# Epoch 4, Step 400: Loss: 0.1136, Cross Entropy: 0.0352, Semantic Loss: 0.7836, Accuracy: 1.0000
# Epoch 4, Step 500: Loss: 0.4041, Cross Entropy: 0.3124, Semantic Loss: 0.9173, Accuracy: 0.8906
# Epoch 4, Step 600: Loss: 0.1119, Cross Entropy: 0.0632, Semantic Loss: 0.4868, Accuracy: 0.9688
# Epoch 4, Step 700: Loss: 0.1566, Cross Entropy: 0.0981, Semantic Loss: 0.5849, Accuracy: 0.9844
# Epoch 4, Step 800: Loss: 0.1266, Cross Entropy: 0.0750, Semantic Loss: 0.5160, Accuracy: 0.9844
# Epoch 4, Step 900: Loss: 0.2237, Cross Entropy: 0.1591, Semantic Loss: 0.6466, Accuracy: 0.9531
# Epoch 4 - Test Accuracy: 0.9778
